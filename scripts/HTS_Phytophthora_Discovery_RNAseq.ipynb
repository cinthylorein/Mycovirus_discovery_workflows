# %% [markdown]
# # <u> Virus Discovery from HTS data derived from Phytophthora RNA-seq data from Scion and Massey - Single library with no barcodes

# %% [markdown]
# # <u>Phase I: Quality Control
# ## <i>This Notebook Performs QC on Paired-End HTS Data</i>
# #### Last Revision: July  2022
# #### Author: Karmun Chooi
# #### This analysis done by Karmun Chooi

# %% [markdown]
# ## <u>Step I: Establish Data Management Structure on PowerPlant</u>

# %%
# Define the user as a variable
USER="hrakmc"
PROJECTNAME="PhytophthoraVirus_Discovery_2022"
# Define the project directory and temp subdirectory as a variable
PROJECT="/workspace/$USER/$PROJECTNAME"

# Define the location of various subdirectories within PROJECT


RAW=$PROJECT/000.raw
FASTQC_RAW=$PROJECT/001.fastqc_raw
TRIMMOMATIC=$PROJECT/002.trimmomatic
FASTQC_TRIMMOMATIC=$PROJECT/003.fastqc_trim
TEMP="$PROJECT/TEMP"

# %% [markdown]
# ### Create analysis directories
# At this point, we have not actually created any directories... only defined what the directory is going to be called when we create it. We still need to actually create the directories.
#
# We use the Unix shell command mkdir to create the directories. The switch -p suppresses error messages if the directory already exists.

# %%
# Create the project directory

mkdir -p $PROJECT

# Create project subdirectories

mkdir -p $RAW
mkdir -p $FASTQC_RAW
mkdir -p $TRIMMOMATIC
mkdir -p $FASTQC_TRIMMOMATIC
mkdir -p $TEMP

# %%
# Create symlinks of all input fastq files and put them in $RAW
ln -s /input/genomic/viral/Phytophthora/MGS00464_Illumina_RNA-seq/X201SC21060659-Z01-F001/raw_data/RNAR2/*.fq.gz $RAW
ln -s /input/genomic/viral/Phytophthora/MGS00464_Illumina_RNA-seq/X201SC21060659-Z01-F001/raw_data/RNAR3/*.fq.gz $RAW

# %%
# Change filenames to comply with naming requirements for downstream steps
# Make the filename have_R1 and R2 in the name to represent F = R1 and R = R2, 1 = R1 and 2 = R2

# %% [markdown]
# ls -s $RAW

# %% [markdown]
# squeue

# %% [markdown]
# ## <u>Step II Part 1: FastQC RAW Data</u>
# - The input for this step is the raw data from the provider in FASTQ format
# - The output from this step are the HTML FASTQC Reports

# %%
module avail

# %% [raw]
# nano

# %%
# Define the location for the QC reports:
OUT="${PROJECT}/001.fastqc_raw"
LOG="${OUT}/logs"



COMMAND="fastqc --nogroup -q -t 2 -o ${OUT} ${RAW}/RNAR1_2.fq.gz"



sbatch << EOF
#!/bin/bash
#SBATCH -J fast_QC
#SBATCH -o ${LOG}/FQC2.out
#SBATCH -e ${LOG}/FQC2.err
#SBATCH --cpus-per-task=16
#SBATCH --mem=10G
#SBATCH --time=00:20:00

# Load the FastQC module:
module load FastQC/0.11.7

${COMMAND}


EOF
squeue


module unload FastQC/0.11.7
# Out:
# Submitted batch job 361190
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#             361189      fast nf-trim_   cflsjt PD       0:00      1 (None)
#             361188      fast nf-qcraw   cflsjt PD       0:00      1 (None)
#             361187      fast nf-trim_   cflsjt PD       0:00      1 (None)
#             361186      fast nf-qcraw   cflsjt PD       0:00      1 (None)
#             361185      fast nf-trim_   cflsjt PD       0:00      1 (None)
#             361184      fast nf-trim_   cflsjt PD       0:00      1 (None)
#             361183      fast nf-qcraw   cflsjt PD       0:00      1 (None)
#             361182      fast nf-qcraw   cflsjt PD       0:00      1 (Priority)
#             361181      fast nf-trim_   cflsjt PD       0:00      1 (Priority)
#             361180      fast nf-trim_   cflsjt PD       0:00      1 (Priority)
#             361179      fast nf-qcraw   cflsjt PD       0:00      1 (Priority)
# ...

# %%
# Define the location for the QC reports:
OUT="${PROJECT}/001.fastqc_raw"
LOG="${OUT}/logs"

mkdir -p $LOG


COMMAND="fastqc --nogroup -q -t 2 -o ${OUT} ${RAW}/RNAR2_1.fq.gz"



sbatch << EOF
#!/bin/bash
#SBATCH -J fast_QC
#SBATCH -o ${LOG}/FQC1.out
#SBATCH -e ${LOG}/FQC1.err
#SBATCH --cpus-per-task=16
#SBATCH --mem=10G
#SBATCH --time=00:20:00

# Load the FastQC module:
module load FastQC/0.11.7

${COMMAND}


EOF
squeue


module unload FastQC/0.11.7
# Out:
# Submitted batch job 361884
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#             361885      fast nf-trim_   cflsjt PD       0:00      1 (None)
#             361883      fast nf-qcraw   cflsjt PD       0:00      1 (None)
#             361882      fast nf-trim_   cflsjt PD       0:00      1 (None)
#             361881      fast nf-qcraw   cflsjt PD       0:00      1 (None)
#             361880      fast nf-qcraw   cflsjt PD       0:00      1 (None)
#             361879      fast nf-trim_   cflsjt PD       0:00      1 (None)
#             361878      fast nf-qcraw   cflsjt PD       0:00      1 (None)
#             361877      fast nf-trim_   cflsjt PD       0:00      1 (None)
#             349849      fast     meta   cflsxt PD       0:00      1 (Resources)
#             361884      fast  fast_QC   hrakmc PD       0:00      1 (None)
#             361766      fast test_4co   cfprxj  R       0:37      1 aklppb30
# ...

# %%
# Define the location for the QC reports:
OUT="${PROJECT}/001.fastqc_raw"
LOG="${OUT}/logs"



COMMAND="fastqc --nogroup -q -t 2 -o ${OUT} ${RAW}/RNAR2_2.fq.gz"



sbatch << EOF
#!/bin/bash
#SBATCH -J fast_QC
#SBATCH -o ${LOG}/FQC2.out
#SBATCH -e ${LOG}/FQC2.err
#SBATCH --cpus-per-task=16
#SBATCH --mem=10G
#SBATCH --time=00:20:00

# Load the FastQC module:
module load FastQC/0.11.7

${COMMAND}


EOF
squeue


module unload FastQC/0.11.7
# Out:
# Submitted batch job 361921
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#             361892      fast nf-trim_   cflsjt CG       0:02      1 wkoppg34
#             361886      fast nf-trim_   cflsjt CG       0:06      1 wkoppb30
#             361862      fast nf-qcraw   cflsjt CG       0:12      1 wkoppb30
#             361922      fast nf-trim_   cflsjt PD       0:00      1 (None)
#             361920      fast nf-qcraw   cflsjt PD       0:00      1 (None)
#             361919      fast nf-qcraw   cflsjt PD       0:00      1 (None)
#             361918      fast nf-trim_   cflsjt PD       0:00      1 (None)
#             361917      fast nf-trim_   cflsjt PD       0:00      1 (None)
#             361916      fast nf-qcraw   cflsjt PD       0:00      1 (None)
#             361915      fast nf-qcraw   cflsjt PD       0:00      1 (None)
#             361914      fast nf-trim_   cflsjt PD       0:00      1 (None)
# ...

# %%
# Define the location for the QC reports:
OUT="${PROJECT}/001.fastqc_raw"
LOG="${OUT}/logs"

mkdir -p $LOG


COMMAND="fastqc --nogroup -q -t 2 -o ${OUT} ${RAW}/RNAR3_1.fq.gz"



sbatch << EOF
#!/bin/bash
#SBATCH -J fast_QC
#SBATCH -o ${LOG}/FQC1.out
#SBATCH -e ${LOG}/FQC1.err
#SBATCH --cpus-per-task=16
#SBATCH --mem=10G
#SBATCH --time=00:20:00

# Load the FastQC module:
module load FastQC/0.11.7

${COMMAND}


EOF
squeue


module unload FastQC/0.11.7
# Out:
# Submitted batch job 361947
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#             361878      fast nf-qcraw   cflsjt CG       0:13      1 wkoppg34
#             361948      fast nf-trim_   cflsjt PD       0:00      1 (None)
#             361946      fast nf-qcraw   cflsjt PD       0:00      1 (None)
#             361945      fast nf-trim_   cflsjt PD       0:00      1 (None)
#             361944      fast nf-trim_   cflsjt PD       0:00      1 (None)
#             361943      fast nf-qcraw   cflsjt PD       0:00      1 (None)
#             361942      fast nf-trim_   cflsjt PD       0:00      1 (None)
#             361941      fast nf-qcraw   cflsjt PD       0:00      1 (None)
#             361940      fast nf-trim_   cflsjt PD       0:00      1 (None)
#             361939      fast nf-qcraw   cflsjt PD       0:00      1 (None)
#             361938      fast nf-trim_   cflsjt PD       0:00      1 (None)
# ...

# %%
# Define the location for the QC reports:
OUT="${PROJECT}/001.fastqc_raw"
LOG="${OUT}/logs"



COMMAND="fastqc --nogroup -q -t 2 -o ${OUT} ${RAW}/RNAR3_2.fq.gz"



sbatch << EOF
#!/bin/bash
#SBATCH -J fast_QC
#SBATCH -o ${LOG}/FQC2.out
#SBATCH -e ${LOG}/FQC2.err
#SBATCH --cpus-per-task=16
#SBATCH --mem=10G
#SBATCH --time=00:20:00

# Load the FastQC module:
module load FastQC/0.11.7

${COMMAND}


EOF
squeue


module unload FastQC/0.11.7
# Out:
# Submitted batch job 361965
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#             361964      fast nf-trim_   cflsjt PD       0:00      1 (None)
#             361963      fast nf-trim_   cflsjt PD       0:00      1 (None)
#             361962      fast nf-qcraw   cflsjt PD       0:00      1 (None)
#             361961      fast nf-trim_   cflsjt PD       0:00      1 (None)
#             361960      fast nf-qcraw   cflsjt PD       0:00      1 (None)
#             361959      fast nf-qcraw   cflsjt PD       0:00      1 (None)
#             361958      fast nf-trim_   cflsjt PD       0:00      1 (None)
#             361957      fast nf-qcraw   cflsjt PD       0:00      1 (None)
#             361956      fast nf-trim_   cflsjt PD       0:00      1 (None)
#             361955      fast nf-trim_   cflsjt PD       0:00      1 (None)
#             361954      fast nf-qcraw   cflsjt PD       0:00      1 (None)
# ...

# %%
# How to read the error files:
# cat ${LOG}/IndexLepidium.err

# %%
# How to check progress
# sacct -j 33276

# %%
#sacct -j 50176
# Out:
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 50176             SMRNA      short powerplant         16  COMPLETED      0:0
# 50176.batch       batch            powerplant         16  COMPLETED      0:0
# 50176.extern     extern            powerplant         16  COMPLETED      0:0

# %% [markdown]
# ### Un-merge (de-interleave) the filtered fastq files
# * The other programs in our workflow use standard non-interleaved files, so we unmerge them.
# * The input is the merged fastq files
# * The output are the unmerged fastq files

# %% [markdown]
# <u>Step III: TRIMMOMATIC</u>
# * Now that the reads are filtered, we will remove adapters, over-represented sequences, and poor-quality bases from the reads
# * The command specifies that bases with quality scores less than 30 will be clipped
# * Also, after clipping, the min length for a read will be 50 bp
# * The `Illumina.fa` file contains the TruSeq adapter sequences and homo-polymer sequences to clip
#   * This file needs to be edited to contain the appropriate sequences.
# * The input for this step are the SortMeRNA filtered reads
# * The output are the trimmed reads

# %%
# Run the Trimmomatic program on the filtered data to remove Illumina adapters, homo-polymers, and low quality reads:
  # Note that to do this, it is necessary to edit the file containing the adapter sequences
  # to include all sequences that you wish to remove:
  # This file is called Illumina.fa and is in the 000.raw directory.


OUT="${PROJECT}/002.trimmomatic"
UNPAIRED="${OUT}/unpaired"
LOG="${OUT}/logs"
TRIMMOMATIC="/workspace/cflcyd/software/Trimmomatic/Trimmomatic-0.39/trimmomatic-0.39.jar"


mkdir -p $UNPAIRED
mkdir -p $LOG

# Set the path to the adapter file:
CLIP="/workspace/hrakmc/Lepidium_Virus_Discovery_CO_LSo_1_experiment/Illumina.fa"

        In_File1=$RAW/RNAR1_1.fq.gz
        In_File2=$RAW/RNAR1_2.fq.gz
        Out_PAIRED_1=${OUT}/RNAR1_1_trimmomatic_R1.fq
        Out_UNPAIRED_1=${UNPAIRED}/RNAR1_1_trimmomatic_unpaired_1.fq
        Out_PAIRED_2=${OUT}/RNAR1_2_trimmomatic_R2.fq
        Out_UNPAIRED_2=${UNPAIRED}/RNAR1_2_trimmomatic_unpaired_2.fq
        COMMAND="java -jar -Xms8G -Xmx8G \
                 ${TRIMMOMATIC} PE -threads 3 \
                <(zcat ${In_File1}) <(zcat ${In_File2}) \
                 ${Out_PAIRED_1} ${Out_UNPAIRED_1} ${Out_PAIRED_2} ${Out_UNPAIRED_2} \
                 ILLUMINACLIP:${CLIP}:2:30:10 SLIDINGWINDOW:5:20 MINLEN:50"
 
sbatch << EOF
#!/bin/bash
#SBATCH -J TRIM
#SBATCH -o ${LOG}/Trim1.out
#SBATCH -e ${LOG}/Trim1.err
#SBATCH --cpus-per-task=16
#SBATCH --mem=10G
#SBATCH --time=06:00:00
#SBATCH --mail-user=karmun.chooi@plantandfood.co.nz
#SBATCH --mail-type=ALL


# Load the Trimmomatic module:
module load Trimmomatic/0.36

${COMMAND}


EOF
squeue


module unload Trimmomatic/0.36

# It is critical to set the -X settings for Java for the program to run correctly
# Here, the VM is instantiated with 8GB of heap space, with a max of 8GB...

# %% [markdown]
# # Run the Trimmomatic program on the filtered data to remove Illumina adapters, homo-polymers, and low quality reads:
#   # Note that to do this, it is necessary to edit the file containing the adapter sequences
#   # to include all sequences that you wish to remove:
#   # This file is called Illumina.fa and is in the 000.raw directory.
#
#
# OUT="${PROJECT}/002.trimmomatic"
# UNPAIRED="${OUT}/unpaired"
# LOG="${OUT}/logs"
# TRIMMOMATIC="/workspace/cflcyd/software/Trimmomatic/Trimmomatic-0.39/trimmomatic-0.39.jar"
#
#
# mkdir -p $UNPAIRED
# mkdir -p $LOG
#
# # Set the path to the adapter file:
# CLIP="/workspace/hrakmc/Lepidium_Virus_Discovery_CO_LSo_1_experiment/Illumina.fa"
#
#         In_File1=$RAW/RNAR2_1.fq.gz
#         In_File2=$RAW/RNAR2_2.fq.gz
#         Out_PAIRED_1=${OUT}/RNAR2_1_trimmomatic_R1.fq
#         Out_UNPAIRED_1=${UNPAIRED}/RNAR2_1_trimmomatic_unpaired_1.fq
#         Out_PAIRED_2=${OUT}/RNAR2_2_trimmomatic_R2.fq
#         Out_UNPAIRED_2=${UNPAIRED}/RNAR2_2_trimmomatic_unpaired_2.fq
#         COMMAND="java -jar -Xms8G -Xmx8G \
#                  ${TRIMMOMATIC} PE -threads 3 \
#                 <(zcat ${In_File1}) <(zcat ${In_File2}) \
#                  ${Out_PAIRED_1} ${Out_UNPAIRED_1} ${Out_PAIRED_2} ${Out_UNPAIRED_2} \
#                  ILLUMINACLIP:${CLIP}:2:30:10 SLIDINGWINDOW:5:20 MINLEN:50"
#
# sbatch << EOF
# #!/bin/bash
# #SBATCH -J TRIM
# #SBATCH -o ${LOG}/Trim2.out
# #SBATCH -e ${LOG}/Trim2.err
# #SBATCH --cpus-per-task=16
# #SBATCH --mem=10G
# #SBATCH --time=06:00:00
# #SBATCH --mail-user=karmun.chooi@plantandfood.co.nz
# #SBATCH --mail-type=ALL
#
#
# # Load the Trimmomatic module:
# module load Trimmomatic/0.36
#
# ${COMMAND}
#
#
# EOF
# squeue
#
#
# module unload Trimmomatic/0.36
#
# # It is critical to set the -X settings for Java for the program to run correctly
# # Here, the VM is instantiated with 8GB of heap space, with a max of 8GB...

# %% [raw]
# # Run the Trimmomatic program on the filtered data to remove Illumina adapters, homo-polymers, and low quality reads:
#   # Note that to do this, it is necessary to edit the file containing the adapter sequences
#   # to include all sequences that you wish to remove:
#   # This file is called Illumina.fa and is in the 000.raw directory.
#
#
# OUT="${PROJECT}/002.trimmomatic"
# UNPAIRED="${OUT}/unpaired"
# LOG="${OUT}/logs"
# TRIMMOMATIC="/workspace/cflcyd/software/Trimmomatic/Trimmomatic-0.39/trimmomatic-0.39.jar"
#
#
# mkdir -p $UNPAIRED
# mkdir -p $LOG
#
# # Set the path to the adapter file:
# CLIP="/workspace/hrakmc/Lepidium_Virus_Discovery_CO_LSo_1_experiment/Illumina.fa"
#
#         In_File1=$RAW/RNAR3_1.fq.gz
#         In_File2=$RAW/RNAR3_2.fq.gz
#         Out_PAIRED_1=${OUT}/RNAR3_1_trimmomatic_R1.fq
#         Out_UNPAIRED_1=${UNPAIRED}/RNAR3_1_trimmomatic_unpaired_1.fq
#         Out_PAIRED_2=${OUT}/RNAR3_2_trimmomatic_R2.fq
#         Out_UNPAIRED_2=${UNPAIRED}/RNAR3_2_trimmomatic_unpaired_2.fq
#         COMMAND="java -jar -Xms8G -Xmx8G \
#                  ${TRIMMOMATIC} PE -threads 3 \
#                 <(zcat ${In_File1}) <(zcat ${In_File2}) \
#                  ${Out_PAIRED_1} ${Out_UNPAIRED_1} ${Out_PAIRED_2} ${Out_UNPAIRED_2} \
#                  ILLUMINACLIP:${CLIP}:2:30:10 SLIDINGWINDOW:5:20 MINLEN:50"
#
# sbatch << EOF
# #!/bin/bash
# #SBATCH -J TRIM
# #SBATCH -o ${LOG}/Trim3.out
# #SBATCH -e ${LOG}/Trim3.err
# #SBATCH --cpus-per-task=16
# #SBATCH --mem=10G
# #SBATCH --time=06:00:00
# #SBATCH --mail-user=karmun.chooi@plantandfood.co.nz
# #SBATCH --mail-type=ALL
#
#
# # Load the Trimmomatic module:
# module load Trimmomatic/0.36
#
# ${COMMAND}
#
#
# EOF
# squeue
#
#
# module unload Trimmomatic/0.36
#
# # It is critical to set the -X settings for Java for the program to run correctly
# # Here, the VM is instantiated with 8GB of heap space, with a max of 8GB...

# %%
cat ${PROJECT}/002.trimmomatic/logs/Trim.err
# Out:
# /var/spool/slurmd/job58926/slurm_script: line 15: syntax error near unexpected token `)'
# ...

# %%
IN="${PROJECT}/002.trimmomatic"
OUT="${PROJECT}/003.fastqc_trim"
LOG="${OUT}/logs"

mkdir -p $LOG

        COMMAND="fastqc --nogroup -q -t 2 -o ${OUT} ${IN}/Library4_L2_R1_trimmomatic_R1.fq"




sbatch << EOF
#!/bin/bash
#SBATCH -J fast_QC1
#SBATCH -o ${LOG}/FQC1.out
#SBATCH -e ${LOG}/FQC1.err
#SBATCH --cpus-per-task=16
#SBATCH --mem=10G
#SBATCH --time=00:20:00
#SBATCH --dependency=afterok:114406
#SBATCH --mail-user=karmun.chooi@plantandfood.co.nz
#SBATCH --mail-type=ALL

# Load the FastQC module:
module load FastQC/0.11.7

${COMMAND}


EOF
squeue


module unload FastQC/0.11.7
# Out:
# Submitted batch job 333785
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#             333785      fast fast_QC1   hrakmc PD       0:00      1 (None)
#             333529      long     GDDH   hrachd  R   21:08:10      1 aklppb30
#             333541      long  baccata   hrachd  R   20:12:03      1 aklppb30
#             333556    medium SUPERNOV   hralll  R   19:03:36      1 aklppb30
#             333614    medium    rails   hralll  R   17:38:18      1 aklppb30
#             333621    medium abyss_lr   hralll  R   16:21:49      1 aklppb30
#             333619    medium    abyss   hralll  R   16:33:09      1 aklppb40
#             333784     short hic_hap_   hraijc  R       9:23      1 aklppb30
#             333783     short hic_hap_   hraijc  R       9:27      1 aklppb40

# %%
IN="${PROJECT}/002.trimmomatic"
OUT="${PROJECT}/003.fastqc_trim"
LOG="${OUT}/logs"


        COMMAND="fastqc --nogroup -q -t 2 -o ${OUT} ${IN}/Library4_L2_R2_trimmomatic_R2.fq"




sbatch << EOF
#!/bin/bash
#SBATCH -J fast_QC2
#SBATCH -o ${LOG}/FQC2.out
#SBATCH -e ${LOG}/FQC2.err
#SBATCH --cpus-per-task=16
#SBATCH --mem=10G
#SBATCH --time=00:20:00
#SBATCH --dependency=afterok:114406
#SBATCH --mail-user=karmun.chooi@plantandfood.co.nz
#SBATCH --mail-type=ALL

# Load the FastQC module:
module load FastQC/0.11.7

${COMMAND}


EOF
squeue


module unload FastQC/0.11.7
# Out:
# Submitted batch job 333786
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#             333786      fast fast_QC2   hrakmc PD       0:00      1 (None)
#             333785      fast fast_QC1   hrakmc  R       0:15      1 wkoppg31
#             333529      long     GDDH   hrachd  R   21:08:25      1 aklppb30
#             333541      long  baccata   hrachd  R   20:12:18      1 aklppb30
#             333556    medium SUPERNOV   hralll  R   19:03:51      1 aklppb30
#             333614    medium    rails   hralll  R   17:38:33      1 aklppb30
#             333621    medium abyss_lr   hralll  R   16:22:04      1 aklppb30
#             333619    medium    abyss   hralll  R   16:33:24      1 aklppb40
#             333784     short hic_hap_   hraijc  R       9:38      1 aklppb30
#             333783     short hic_hap_   hraijc  R       9:42      1 aklppb40

# %% [markdown]
# # Render notebook to html and markdown
# #cd $PWD
# #module load pfr-python3
# #jupyter nbconvert --to markdown /workspace/$USER/HTS_Lepidium_CO_LSo1.ipynb
# #jupyter nbconvert --to html /workspace/$USER/HTS_Lepidium_CO_LSo1.ipynb
# #module unload pfr-python3

# %%
# <u>Extracting and de novo assembly: Phase II
## Step I: BOWTIE2 - MAKING REF INDEX</u>
The aim is to next step is to match the reads to host genome and remove host reads.
To achieve this task, we must first build the index that will be used as the reference.

# %% [raw]
# ### How to Open GZ Files without Unzipping
#
# You can use the zcat command in Linux to view the contents of a compressed file without unzipping it. It works for all compression utilities, including Gzip.
#
#
# #### View the contents of a GZIP compressed file
# zcat compressed_file1.gz
#
# ### How to Unzip GZ Files
# You can unzip GZ files in Linux by adding the -d flag to the Gzip/Gunzip command. All the same flags we used above can be applied. The GZ file will be removed by default after we uncompressed it unless we use the -k flag. Below we will unzip the GZ files we compressed in the same directory.
#
# #### Unzip GZ file
# gzip -dv compressed_file1.gz
# compressed_file1.gz:     52.8% -- replaced with compressed_file1
#
#
# In the example below, the following commands are equivalents.
#
#
# Using the gunzip command:
#
# #### Unzip GZ file
# gunzip file.gz
#
#
# Using the gzip -d command:
#
# ##### Unzip GZ file
#
# gzip -d file.gz

# %% [markdown]
# gunzip $PROJECT/Sclerotinia_sclerotiorum_GCA_000146945.2_ASM14694v2_genomic.fna.gz

# %% [raw]
# OUT="$PROJECT/010.PhytophthoraHostIndex"
# LOG="${OUT}/logs"
#
#
# mkdir -p $OUT
# mkdir -p $LOG
#
# REF="/input/genomic/viral/Phytophthora/P_agathidicida_3770_56996300_v2.fna"
# INDEX="${OUT}/bt2index"
#
# mkdir -p $INDEX
#
#
# COMMAND="bowtie2-build $REF $INDEX"
# echo $COMMAND
#
#
#
# sbatch << EOF
# #!/bin/bash
# #SBATCH -J BowtieBuildPhytophthora
# #SBATCH -o ${LOG}/IndexPhytophthora.out
# #SBATCH -e ${LOG}/IndexPhytophthora.err
# #SBATCH --cpus-per-task=16
# #SBATCH --mem=10G
# #SBATCH --time=01:00:00
# #SBATCH --mail-user=karmun.chooi@plantandfood.co.nz
# #SBATCH --mail-type=ALL
#
# # Load the Bowtie2 module:
# module load bowtie2/2.3.4.3
#
# ${COMMAND}
#
#
# EOF
# squeue
#
#
#
# module unload bowtie2/2.3.4.3

# %% [raw]
# IN="$PROJECT/002.trimmomatic"
# OUT="$PROJECT/004.MapPhytophthora"
# LOG="$OUT/logs"
#
# mkdir -p $OUT
# mkdir -p $LOG
#
#
#
# INDEX="/workspace/hrakmc/PhytophthoraVirus_Discovery_2022/010.PhytophthoraHostIndex/bt2index"
#
# OPTIONS="--end-to-end --sensitive "
#
# COMMAND="bowtie2 $OPTIONS -x $INDEX -1 $IN/RNAR1_1_trimmomatic_R1.fq -2 $IN/RNAR1_2_trimmomatic_R2.fq --un-conc-gz ${OUT}/RNAR1.non-Phytophthora.fq.gz"
# echo $COMMAND
#
# sbatch << EOF
# #!/bin/bash
# #SBATCH -J BowtieMapHost
# #SBATCH -o ${LOG}/MapPhytophthora1.out
# #SBATCH -e ${LOG}/MapPhytophthora1.err
# #SBATCH --cpus-per-task=16
# #SBATCH --mem=18G
# #SBATCH --dependency=afterok:363476
# #SBATCH --time=24:00:00
# #SBATCH --mail-user=karmun.chooi@plantandfood.co.nz
# #SBATCH --mail-type=ALL
#
# # Load the Bowtie2 module:
# module load bowtie2/2.3.4.3
#
# ${COMMAND}
#
#
# EOF
# squeue
#
#
# module unload bowtie2/2.3.4.3

# %% [raw]
# IN="$PROJECT/002.trimmomatic"
# OUT="$PROJECT/004.MapPhytophthora"
# LOG="$OUT/logs"
#
# mkdir -p $OUT
# mkdir -p $LOG
#
#
#
# INDEX="/workspace/hrakmc/PhytophthoraVirus_Discovery_2022/010.PhytophthoraHostIndex/bt2index"
#
# OPTIONS="--end-to-end --sensitive "
#
# COMMAND="bowtie2 $OPTIONS -x $INDEX -1 $IN/RNAR2_1_trimmomatic_R1.fq -2 $IN/RNAR2_2_trimmomatic_R2.fq --un-conc-gz ${OUT}/RNAR2.non-Phytophthora.fq.gz"
# echo $COMMAND
#
# sbatch << EOF
# #!/bin/bash
# #SBATCH -J BowtieMapHost
# #SBATCH -o ${LOG}/MapPhytophthora2.out
# #SBATCH -e ${LOG}/MapPhytophthora2.err
# #SBATCH --cpus-per-task=16
# #SBATCH --mem=18G
# #SBATCH --dependency=afterok:363497
# #SBATCH --time=24:00:00
# #SBATCH --mail-user=karmun.chooi@plantandfood.co.nz
# #SBATCH --mail-type=ALL
#
# # Load the Bowtie2 module:
# module load bowtie2/2.3.4.3
#
# ${COMMAND}
#
#
# EOF
# squeue
#
#
# module unload bowtie2/2.3.4.3

# %% [raw]
# IN="$PROJECT/002.trimmomatic"
# OUT="$PROJECT/004.MapPhytophthora"
# LOG="$OUT/logs"
#
# mkdir -p $OUT
# mkdir -p $LOG
#
#
#
# INDEX="/workspace/hrakmc/PhytophthoraVirus_Discovery_2022/010.PhytophthoraHostIndex/bt2index"
#
# OPTIONS="--end-to-end --sensitive "
#
# COMMAND="bowtie2 $OPTIONS -x $INDEX -1 $IN/RNAR3_1_trimmomatic_R1.fq -2 $IN/RNAR3_2_trimmomatic_R2.fq --un-conc-gz ${OUT}/RNAR3.non-Phytophthora.fq.gz"
# echo $COMMAND
#
# sbatch << EOF
# #!/bin/bash
# #SBATCH -J BowtieMapHost
# #SBATCH -o ${LOG}/MapPhytophthora3.out
# #SBATCH -e ${LOG}/MapPhytophthora3.err
# #SBATCH --cpus-per-task=16
# #SBATCH --mem=18G
# #SBATCH --dependency=afterok:363575
# #SBATCH --time=24:00:00
# #SBATCH --mail-user=karmun.chooi@plantandfood.co.nz
# #SBATCH --mail-type=ALL
#
# # Load the Bowtie2 module:
# module load bowtie2/2.3.4.3
#
# ${COMMAND}
#
#
# EOF
# squeue
#
#
# module unload bowtie2/2.3.4.3

# %%
#sacct -j 54429
# Out:
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 54429        BowtieMap+      short powerplant         16    RUNNING      0:0
# 54429.batch       batch            powerplant         16    RUNNING      0:0
# 54429.extern     extern            powerplant         16    RUNNING      0:0

# %%
#squeue
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#              59774      fast  fast_QC   hrakmc PD       0:00      1 (Resources)
#              59791      fast fast_QC2   hrakmc PD       0:00      1 (Dependency)
#              59790      fast fast_QC1   hrakmc PD       0:00      1 (Dependency)
#              59782      fast fast_QC2   hrakmc PD       0:00      1 (Dependency)
#              59781      fast fast_QC1   hrakmc PD       0:00      1 (Dependency)
#              59775      fast    Merge   hrakmc PD       0:00      1 (Priority)
#              59789      fast     TRIM   hrakmc PD       0:00      1 (Dependency)
#              59780      fast  Unmerge   hrakmc PD       0:00      1 (Dependency)
#     58457_[1-1000]      fast  P016_38   hrarxc PD       0:00      1 (Priority)
#     58458_[1-1000]      fast  P016_39   hrarxc PD       0:00      1 (Priority)
#     58456_[1-1000]      fast  P016_37   hrarxc PD       0:00      1 (Priority)
# ...

# %%
#Change the name of the bowtie sequences in 007.MapLepidium E.g:
#CO_LSo_3.non-Lepidium.fq.1.gz -> CO_LSo_3.non-Lepidium_1.fq.gz
#CO_LSo_3.non-Lepidium.fq.2.gz -> CO_LSo_3.non-Lepidium_2.fq.gz

# %%
$PROJECT/004.MapSclerotinia/Library2_L2.non-Sclerotinia.fq.1.gz | sed 's/.fq.1.gz/_1.fq.gz/g'
$PROJECT/004.MapSclerotinia/Library2_L2.non-Sclerotinia.fq.2.gz | sed 's/.fq.2.gz/_2.fq.gz/g'
# Out:
# bash: /workspace/hrakmc/Mycovirus_Discovery_Lib2_2021/004.MapSclerotinia/Library2_L2.non-Sclerotinia.fq.1.gz: Permission denied
# bash: /workspace/hrakmc/Mycovirus_Discovery_Lib2_2021/004.MapSclerotinia/Library2_L2.non-Sclerotinia.fq.2.gz: Permission denied

# %% [raw]
# IN="$PROJECT/004.MapPhytophthora"
# OUT="$PROJECT/005.rnaviralspades"
# LOG="$OUT/logs"
#
# mkdir -p $OUT
# mkdir -p $LOG
#
#
# COMMAND="rnaviralspades.py --pe1-1 $IN/RNAR1.non-Phytophthora_1.fq.gz \
#         --pe1-2 $IN/RNAR1.non-Phytophthora_2.fq.gz -o $OUT"
# echo $COMMAND
#
# sbatch << EOF
# #!/bin/bash
# #SBATCH -J rnaviralspades1
# #SBATCH -o ${LOG}/rnaviralspades1.out
# #SBATCH -e ${LOG}/rnaviralspades1.err
# #SBATCH --cpus-per-task=16
# #SBATCH --mem=20G
# #SBATCH --time=10:00:00
# #SBATCH --mail-user=karmun.chooi@plantandfood.co.nz
# #SBATCH --mail-type=ALL
#
# # Load the SPAdes module:
# module load SPAdes/3.15.4
#
# ${COMMAND}
#
#
# EOF
# squeue
#
#
# module unload SPAdes/3.15.4

# %%
IN="$PROJECT/004.MapPhytophthora"
OUT="$PROJECT/006.rnaviralspades2"
LOG="$OUT/logs"

mkdir -p $OUT
mkdir -p $LOG


COMMAND="rnaviralspades.py --pe1-1 $IN/RNAR2.non-Phytophthora_1.fq.gz \
        --pe1-2 $IN/RNAR2.non-Phytophthora_2.fq.gz -o $OUT"
echo $COMMAND

sbatch << EOF
#!/bin/bash
#SBATCH -J rnaviralspades2
#SBATCH -o ${LOG}/rnaviralspades2.out
#SBATCH -e ${LOG}/rnaviralspades2.err
#SBATCH --cpus-per-task=16
#SBATCH --mem=20G
#SBATCH --time=10:00:00
#SBATCH --mail-user=karmun.chooi@plantandfood.co.nz
#SBATCH --mail-type=ALL
 
# Load the SPAdes module:
module load SPAdes/3.15.4

${COMMAND}


EOF
squeue


module unload SPAdes/3.15.4
# Out:
# rnaviralspades.py --pe1-1 /workspace/hrakmc/PhytophthoraVirus_Discovery_2022/004.MapPhytophthora/RNAR2.non-Phytophthora_1.fq.gz --pe1-2 /workspace/hrakmc/PhytophthoraVirus_Discovery_2022/004.MapPhytophthora/RNAR2.non-Phytophthora_2.fq.gz -o /workspace/hrakmc/PhytophthoraVirus_Discovery_2022/006.rnaviralspades2
# Submitted batch job 379502
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#             349849      fast     meta   cflsxt PD       0:00      1 (Resources)
#             379498      fast     EEMS   hrpemk  R    1:24:02      1 aklppb30
#             335018      long guppy_ca   hrlaxh  R 5-07:22:17      1 wkoppg32
#             333529      long     GDDH   hrachd  R 8-06:25:29      1 aklppb30
#             333541      long  baccata   hrachd  R 8-05:29:22      1 aklppb30
#             358979    medium     canu   hrtjbs  R    9:00:36      1 wkoppg33
#             350050    medium    bwaag   cflmac  R 1-03:23:19      1 wkoppg32
# ...

# %%
IN="$PROJECT/004.MapPhytophthora"
OUT="$PROJECT/007.rnaviralspades3"
LOG="$OUT/logs"

mkdir -p $OUT
mkdir -p $LOG


COMMAND="rnaviralspades.py --pe1-1 $IN/RNAR3.non-Phytophthora_1.fq.gz \
        --pe1-2 $IN/RNAR3.non-Phytophthora_2.fq.gz -o $OUT"
echo $COMMAND

sbatch << EOF
#!/bin/bash
#SBATCH -J rnaviralspades3
#SBATCH -o ${LOG}/rnaviralspades3.out
#SBATCH -e ${LOG}/rnaviralspades3.err
#SBATCH --cpus-per-task=16
#SBATCH --mem=20G
#SBATCH --time=10:00:00
#SBATCH --mail-user=karmun.chooi@plantandfood.co.nz
#SBATCH --mail-type=ALL
 
# Load the SPAdes module:
module load SPAdes/3.15.4

${COMMAND}


EOF
squeue


module unload SPAdes/3.15.4
# Out:
# rnaviralspades.py --pe1-1 /workspace/hrakmc/PhytophthoraVirus_Discovery_2022/004.MapPhytophthora/RNAR3.non-Phytophthora_1.fq.gz --pe1-2 /workspace/hrakmc/PhytophthoraVirus_Discovery_2022/004.MapPhytophthora/RNAR3.non-Phytophthora_2.fq.gz -o /workspace/hrakmc/PhytophthoraVirus_Discovery_2022/007.rnaviralspades3
# Submitted batch job 379503
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#             349849      fast     meta   cflsxt PD       0:00      1 (Resources)
#             379498      fast     EEMS   hrpemk  R    1:24:17      1 aklppb30
#             335018      long guppy_ca   hrlaxh  R 5-07:22:32      1 wkoppg32
#             333529      long     GDDH   hrachd  R 8-06:25:44      1 aklppb30
#             333541      long  baccata   hrachd  R 8-05:29:37      1 aklppb30
#             358979    medium     canu   hrtjbs  R    9:00:51      1 wkoppg33
#             350050    medium    bwaag   cflmac  R 1-03:23:34      1 wkoppg32
# ...

# %%
cat $PROJECT/005.metaspades/logs/metaspades.out
# Out:
# == Warning ==  output dir is not empty! Please, clean output directory before run.
#
#
#
#
# == Error ==  file not found: /workspace/hrakmc/Mycovirus_Discovery_Lib3_2021/004.MapSclerotinia/Library3_L3.non-Sclerotinia_2.fq.gz (right reads, library number: 1, library type: paired-end)
#
# In case you have troubles running SPAdes, you can write to spades.support@cab.spbu.ru
# or report an issue on our GitHub repository github.com/ablab/spades
# Please provide us with params.txt and spades.log files from the output directory.

# %% [markdown]
# IN="$PROJECT/004.MapSclerotinia"
# OUT="$PROJECT/006.spades"
# LOG="$OUT/logs"
#
# mkdir -p $OUT
# mkdir -p $LOG
#
#
# COMMAND="spades.py --pe1-1 $IN/Library4_L2.non-Sclerotinia_1.fq.gz \
#         --pe1-2 $IN/Library4_L2.non-Sclerotinia_2.fq.gz -o $OUT"
# echo $COMMAND
#
# sbatch << EOF
# #!/bin/bash
# #SBATCH -J metaspades
# #SBATCH -o ${LOG}/spades.out
# #SBATCH -e ${LOG}/spades.err
# #SBATCH --cpus-per-task=16
# #SBATCH --mem=20G
# #SBATCH --time=10:00:00
# #SBATCH --mail-user=karmun.chooi@plantandfood.co.nz
# #SBATCH --mail-type=ALL
#
# # Load the SPAdes module:
# module load SPAdes/3.15.4
#
# ${COMMAND}
#
#
# EOF
# squeue
#
#
# module unload SPAdes/3.15.4

# %% [raw]
# IN="PhytophthoraVirus_Discovery_2022/005.rnaviralspades/scaffolds.fasta"
# OUT="PhytophthoraVirus_Discovery_2022/008.blastn/allVirus_nt_Aug2022"
# LOG="$OUT/logs"
#
# mkdir -p $OUT
# mkdir -p $LOG
#
# BLASTDB="/workspace/hrakmc/DBs/NCBI_allVirusnt_DB_AUG2022"
#
#
# COMMAND="blastn -db $BLASTDB -query $IN -outfmt '6 qseqid sacc pident staxid ssciname length mismatch gapopen qstart qend sstart send evalue bitscore qlen'  -max_target_seqs 5 -out $OUT/PhytophthoraVirus_2022_RNA1_nt_names.csv"
# echo $COMMAND
#
# sbatch << EOF
# #!/bin/bash
# #SBATCH -J blastn1
# #SBATCH -o ${LOG}/blastn1.out
# #SBATCH -e ${LOG}/blastn1.err
# #SBATCH --cpus-per-task=16
# #SBATCH --mem=10G
# #SBATCH --time=20:00:00
# #SBATCH --mail-user=karmun.chooi@plantandfood.co.nz
# #SBATCH --mail-type=ALL
#
# # Load the ncbi-blast module:
# module load ncbi-blast/2.11.0
#
# ${COMMAND}
#
#
# EOF
# squeue
#
#
# module unload ncbi-blast/2.11.0

# %%
IN="PhytophthoraVirus_Discovery_2022/006.rnaviralspades2/scaffolds.fasta"
OUT="PhytophthoraVirus_Discovery_2022/008.blastn/allVirus_nt_Aug2022"
LOG="$OUT/logs"

mkdir -p $OUT
mkdir -p $LOG

BLASTDB="/workspace/hrakmc/DBs/NCBI_allVirusnt_DB_AUG2022"


COMMAND="blastn -db $BLASTDB -query $IN -outfmt '6 qseqid sacc pident staxid ssciname length mismatch gapopen qstart qend sstart send evalue bitscore qlen'  -max_target_seqs 5 -out $OUT/PhytophthoraVirus_2022_RNA2_nt_names.csv"
echo $COMMAND

sbatch << EOF
#!/bin/bash
#SBATCH -J blastn2
#SBATCH -o ${LOG}/blastn2.out
#SBATCH -e ${LOG}/blastn2.err
#SBATCH --cpus-per-task=16
#SBATCH --mem=10G
#SBATCH --time=20:00:00
#SBATCH --mail-user=karmun.chooi@plantandfood.co.nz
#SBATCH --mail-type=ALL
 
# Load the ncbi-blast module:
module load ncbi-blast/2.11.0 

${COMMAND}


EOF
squeue


module unload ncbi-blast/2.11.0
# Out:
# blastn -db /workspace/hrakmc/DBs/NCBI_allVirusnt_DB_AUG2022 -query PhytophthoraVirus_Discovery_2022/006.rnaviralspades2/scaffolds.fasta -outfmt '6 qseqid sacc pident staxid ssciname length mismatch gapopen qstart qend sstart send evalue bitscore qlen' -max_target_seqs 5 -out PhytophthoraVirus_Discovery_2022/008.blastn/allVirus_nt_Aug2022/PhytophthoraVirus_2022_RNA2_nt_names.csv
# Submitted batch job 379505
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#             349849      fast     meta   cflsxt PD       0:00      1 (Resources)
#             379498      fast     EEMS   hrpemk  R    1:32:15      1 aklppb30
#             335018      long guppy_ca   hrlaxh  R 5-07:30:30      1 wkoppg32
#             333529      long     GDDH   hrachd  R 8-06:33:42      1 aklppb30
#             333541      long  baccata   hrachd  R 8-05:37:35      1 aklppb30
#             358979    medium     canu   hrtjbs  R    9:08:49      1 wkoppg33
# ...

# %%
IN="PhytophthoraVirus_Discovery_2022/007.rnaviralspades3/scaffolds.fasta"
OUT="PhytophthoraVirus_Discovery_2022/008.blastn/allVirus_nt_Aug2022"
LOG="$OUT/logs"

mkdir -p $OUT
mkdir -p $LOG

BLASTDB="/workspace/hrakmc/DBs/NCBI_allVirusnt_DB_AUG2022"


COMMAND="blastn -db $BLASTDB -query $IN -outfmt '6 qseqid sacc pident staxid ssciname length mismatch gapopen qstart qend sstart send evalue bitscore qlen'  -max_target_seqs 5 -out $OUT/PhytophthoraVirus_2022_RNA3_nt_names.csv"
echo $COMMAND

sbatch << EOF
#!/bin/bash
#SBATCH -J blastn3
#SBATCH -o ${LOG}/blastn3.out
#SBATCH -e ${LOG}/blastn3.err
#SBATCH --cpus-per-task=16
#SBATCH --mem=10G
#SBATCH --time=20:00:00
#SBATCH --mail-user=karmun.chooi@plantandfood.co.nz
#SBATCH --mail-type=ALL
 
# Load the ncbi-blast module:
module load ncbi-blast/2.11.0 

${COMMAND}


EOF
squeue


module unload ncbi-blast/2.11.0
# Out:
# blastn -db /workspace/hrakmc/DBs/NCBI_allVirusnt_DB_AUG2022 -query PhytophthoraVirus_Discovery_2022/007.rnaviralspades3/scaffolds.fasta -outfmt '6 qseqid sacc pident staxid ssciname length mismatch gapopen qstart qend sstart send evalue bitscore qlen' -max_target_seqs 5 -out PhytophthoraVirus_Discovery_2022/008.blastn/allVirus_nt_Aug2022/PhytophthoraVirus_2022_RNA3_nt_names.csv
# Submitted batch job 379506
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#             349849      fast     meta   cflsxt PD       0:00      1 (Resources)
#             379498      fast     EEMS   hrpemk  R    1:32:49      1 aklppb30
#             335018      long guppy_ca   hrlaxh  R 5-07:31:04      1 wkoppg32
#             333529      long     GDDH   hrachd  R 8-06:34:16      1 aklppb30
#             333541      long  baccata   hrachd  R 8-05:38:09      1 aklppb30
#             358979    medium     canu   hrtjbs  R    9:09:23      1 wkoppg33
# ...

# %% [markdown]
# ## Blastx for Phytophthora Virus Discovery RNA-seq data RNA1, 2, 3 samples
# Redoing the analysis with "sacc" that means Subject accession rather than sseqid as this has other text such as ref|| which makes it difficult to merge datasets later

# %%
# Phytophora RNA1
IN="PhytophthoraVirus_Discovery_2022/005.rnaviralspades/scaffolds.fasta"
OUT="PhytophthoraVirus_Discovery_2022/009.blastx/NCBI_RefVirus_aa_August2022"
LOG="$OUT/logs"

mkdir -p $OUT
mkdir -p $LOG

BLASTDB="/workspace/hrakmc/DBs/NCBI_RefVirus_DB_2AUG2022"


COMMAND="blastx -db $BLASTDB -query $IN -outfmt '6 qseqid sacc pident staxid ssciname length mismatch gapopen qstart qend sstart send evalue bitscore qlen'  -max_target_seqs 5 -out $OUT/PhytophthoraVirus_Discovery_RNA1_aa_names.csv"
echo $COMMAND

sbatch << EOF
#!/bin/bash
#SBATCH -J blastxPa1
#SBATCH -o ${LOG}/blastxPa1.out
#SBATCH -e ${LOG}/blastxPa1.err
#SBATCH --cpus-per-task=16
#SBATCH --mem=10G
#SBATCH --time=20:00:00
#SBATCH --mail-user=karmun.chooi@plantandfood.co.nz
#SBATCH --mail-type=ALL
 
# Load the ncbi-blast module:
module load ncbi-blast/2.11.0 

${COMMAND}


EOF
squeue


module unload ncbi-blast/2.11.0
# Out:
# blastx -db /workspace/hrakmc/DBs/NCBI_RefVirus_DB_2AUG2022 -query PhytophthoraVirus_Discovery_2022/005.rnaviralspades/scaffolds.fasta -outfmt '6 qseqid sacc pident staxid ssciname length mismatch gapopen qstart qend sstart send evalue bitscore qlen' -max_target_seqs 5 -out PhytophthoraVirus_Discovery_2022/009.blastx/NCBI_RefVirus_aa_August2022/PhytophthoraVirus_Discovery_RNA1_aa_names.csv
# Submitted batch job 409123
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#             349849      fast     meta   cflsxt PD       0:00      1 (Resources)
#             409084      fast nf-align   cflsjt PD       0:00      1 (Priority)
#             409085      fast nf-align   cflsjt PD       0:00      1 (Priority)
#             409086      fast nf-align   cflsjt PD       0:00      1 (Priority)
#             409087      fast nf-align   cflsjt PD       0:00      1 (Priority)
#             409088      fast nf-align   cflsjt PD       0:00      1 (Priority)
# ...

# %%
# Phytophora RNA2
IN="PhytophthoraVirus_Discovery_2022/006.rnaviralspades2/scaffolds.fasta"
OUT="PhytophthoraVirus_Discovery_2022/009.blastx/NCBI_RefVirus_aa_August2022"
LOG="$OUT/logs"

BLASTDB="/workspace/hrakmc/DBs/NCBI_RefVirus_DB_2AUG2022"


COMMAND="blastx -db $BLASTDB -query $IN -outfmt '6 qseqid sacc pident staxid ssciname length mismatch gapopen qstart qend sstart send evalue bitscore qlen'  -max_target_seqs 5 -out $OUT/PhytophthoraVirus_Discovery_RNA2_aa_names.csv"
echo $COMMAND

sbatch << EOF
#!/bin/bash
#SBATCH -J blastxPa2
#SBATCH -o ${LOG}/blastxPa2.out
#SBATCH -e ${LOG}/blastxPa2.err
#SBATCH --cpus-per-task=16
#SBATCH --mem=10G
#SBATCH --time=20:00:00
#SBATCH --mail-user=karmun.chooi@plantandfood.co.nz
#SBATCH --mail-type=ALL
 
# Load the ncbi-blast module:
module load ncbi-blast/2.11.0 

${COMMAND}


EOF
squeue


module unload ncbi-blast/2.11.0
# Out:
# blastx -db /workspace/hrakmc/DBs/NCBI_RefVirus_DB_2AUG2022 -query PhytophthoraVirus_Discovery_2022/006.rnaviralspades2/scaffolds.fasta -outfmt '6 qseqid sacc pident staxid ssciname length mismatch gapopen qstart qend sstart send evalue bitscore qlen' -max_target_seqs 5 -out PhytophthoraVirus_Discovery_2022/009.blastx/NCBI_RefVirus_aa_August2022/PhytophthoraVirus_Discovery_RNA2_aa_names.csv
# Submitted batch job 409161
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#             349849      fast     meta   cflsxt PD       0:00      1 (Resources)
#             409144      fast nf-align   cflsjt PD       0:00      1 (Priority)
#             409145      fast nf-align   cflsjt PD       0:00      1 (Priority)
#             409146      fast nf-align   cflsjt PD       0:00      1 (Priority)
#             409147      fast nf-align   cflsjt PD       0:00      1 (Priority)
#             409133      fast nf-align   cflsjt PD       0:00      1 (Priority)
# ...

# %%
nano nano # Phytophora RNA3
IN="PhytophthoraVirus_Discovery_2022/007.rnaviralspades3/scaffolds.fasta"
OUT="PhytophthoraVirus_Discovery_2022/009.blastx/NCBI_RefVirus_aa_August2022"
LOG="$OUT/logs"


BLASTDB="/workspace/hrakmc/DBs/NCBI_RefVirus_DB_2AUG2022"


COMMAND="blastx -db $BLASTDB -query $IN -outfmt '6 qseqid sacc pident staxid ssciname length mismatch gapopen qstart qend sstart send evalue bitscore qlen'  -max_target_seqs 5 -out $OUT/PhytophthoraVirus_Discovery_RNA3_aa_names.csv"
echo $COMMAND

sbatch << EOF
#!/bin/bash
#SBATCH -J blastxPa3
#SBATCH -o ${LOG}/blastxPa3.out
#SBATCH -e ${LOG}/blastxPa3.err
#SBATCH --cpus-per-task=16
#SBATCH --mem=10G
#SBATCH --time=20:00:00
#SBATCH --mail-user=karmun.chooi@plantandfood.co.nz
#SBATCH --mail-type=ALL
 
# Load the ncbi-blast module:
module load ncbi-blast/2.11.0 

${COMMAND}


EOF
squeue


module unload ncbi-blast/2.11.0

# %% [markdown]
# IN="Mycovirus_Discovery_Lib1_2021/006.metaspades/contigs.fasta"
# OUT="Mycovirus_Discovery_Lib1_2021/009.blastx/RefVirus_aa_Aug2022"
# LOG="$OUT/logs"
#
# mkdir -p $OUT
# mkdir -p $LOG
#
# BLASTDB="/workspace/hrakmc/DBs/NCBI_RefVirus_DB_2AUG2022"
#
#
# COMMAND="blastx -db $BLASTDB -query $IN -outfmt '6 qseqid sacc pident staxid ssciname length mismatch gapopen qstart qend sstart send evalue bitscore qlen'  -max_target_seqs 5 -out $OUT/Mycovirus_Discovery_Lib1_2021_aa_names.csv"
# echo $COMMAND
#
# sbatch << EOF
# #!/bin/bash
# #SBATCH -J blastx
# #SBATCH -o ${LOG}/blastx.out
# #SBATCH -e ${LOG}/blastx.err
# #SBATCH --cpus-per-task=16
# #SBATCH --mem=10G
# #SBATCH --time=20:00:00
# #SBATCH --mail-user=karmun.chooi@plantandfood.co.nz
# #SBATCH --mail-type=ALL
#
# # Load the ncbi-blast module:
# module load ncbi-blast/2.11.0
#
# ${COMMAND}
#
#
# EOF
# squeue
#
#
# module unload ncbi-blast/2.11.0

# %%
cat /workspace/hrakmc/Mycovirus_Discovery_Lib1_2021/006.metaspades/logs/metaspades.out
# Out:
# == Warning ==  output dir is not empty! Please, clean output directory before run.
#
#
#
#
# == Error ==  file not found: /workspace/hrakmc/Mycovirus_Discovery_Lib1_2021/005.MapSclerotinia/Library1_L2.non-Sclerotinia_2.fq.gz (right reads, library number: 1, library type: paired-end)
#
# In case you have troubles running SPAdes, you can write to spades.support@cab.spbu.ru
# or report an issue on our GitHub repository github.com/ablab/spades
# Please provide us with params.txt and spades.log files from the output directory.

# %%
scancel 64418
